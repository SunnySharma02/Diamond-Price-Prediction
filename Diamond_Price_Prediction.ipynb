# %% [markdown]
# #**Project Name - Diamond Price Prediction**
# ######Author - Sunny Sharma
#
# ---

# %% [markdown]
# #Import Library Pandas

# %%
import pandas as pd

# %% [markdown]
# #Read Data

# %%
data=pd.read_csv('https://www.dropbox.com/s/5saczr8wmjketen/DiamondPrices.csv?dl=1')

# %%
data
# Out:
#           sn  carat        cut color clarity  depth  table  price     x     y  \
# 0          1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1          2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2          3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3          4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4          5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935  53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936  53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937  53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938  53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939  53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#           z
# 0      2.43
# ...

# %% [markdown]
# #Importing OrdinalEncoder

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
data.loc[:,['cut','color','clarity']]=oe.fit_transform(data[['cut','color','clarity']])

# %% [markdown]
# #Functions

# %% [markdown]
# .head() Function

# %%
data.head()
# Out:
#    sn  carat  cut  color  clarity  depth  table  price     x     y     z
# 0   1   0.23  2.0    1.0      3.0   61.5   55.0    326  3.95  3.98  2.43
# 1   2   0.21  3.0    1.0      2.0   59.8   61.0    326  3.89  3.84  2.31
# 2   3   0.23  1.0    1.0      4.0   56.9   65.0    327  4.05  4.07  2.31
# 3   4   0.29  3.0    5.0      5.0   62.4   58.0    334  4.20  4.23  2.63
# 4   5   0.31  1.0    6.0      3.0   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# .tail() Function

# %%
data.tail()
# Out:
#           sn  carat  cut  color  clarity  depth  table  price     x     y  \
# 53935  53936   0.72  2.0    0.0      2.0   60.8   57.0   2757  5.75  5.76
# 53936  53937   0.72  1.0    0.0      2.0   63.1   55.0   2757  5.69  5.75
# 53937  53938   0.70  4.0    0.0      2.0   62.8   60.0   2757  5.66  5.68
# 53938  53939   0.86  3.0    4.0      3.0   61.0   58.0   2757  6.15  6.12
# 53939  53940   0.75  2.0    0.0      3.0   62.2   55.0   2757  5.83  5.87
#
#           z
# 53935  3.50
# 53936  3.61
# 53937  3.56
# 53938  3.74
# 53939  3.64

# %% [markdown]
# .info() Function

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sn       53940 non-null  int64
#  1   carat    53940 non-null  float64
#  2   cut      53940 non-null  float64
#  3   color    53940 non-null  float64
#  4   clarity  53940 non-null  float64
#  5   depth    53940 non-null  float64
#  6   table    53940 non-null  float64
#  7   price    53940 non-null  int64
#  8   x        53940 non-null  float64
#  9   y        53940 non-null  float64
#  10  z        53940 non-null  float64
# dtypes: float64(9), int64(2)
# memory usage: 4.5 MB

# %% [markdown]
# .describe() Function

# %%
data.describe()
# Out:
#                  sn         carat           cut         color       clarity  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940      2.553003      2.594197      3.835150
# std    15571.281097      0.474011      1.027708      1.701105      1.724591
# min        1.000000      0.200000      0.000000      0.000000      0.000000
# 25%    13485.750000      0.400000      2.000000      1.000000      2.000000
# 50%    26970.500000      0.700000      2.000000      3.000000      4.000000
# 75%    40455.250000      1.040000      3.000000      4.000000      5.000000
# max    53940.000000      5.010000      4.000000      6.000000      7.000000
#
#               depth         table         price             x             y  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean      61.749405     57.457184   3932.799722      5.731157      5.734526
# ...

# %% [markdown]
# .value_counts() Function

# %%
data.value_counts('price')
# Out:
# price
# 605      132
# 802      127
# 625      126
# 828      125
# 776      124
#         ...
# 9510       1
# 9507       1
# 9504       1
# 9503       1
# 18823      1
# Length: 11602, dtype: int64

# %% [markdown]
# .shape Function

# %%
data.shape
# Out:
# (53940, 11)

# %% [markdown]
# .columns Function

# %%
data.columns
# Out:
# Index(['sn', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price',
#        'x', 'y', 'z'],
#       dtype='object')

# %% [markdown]
# #Define y and X

# %%
y=data['price']
y.shape
# Out:
# (53940,)

# %%
X=data[['cut','color','clarity','sn','carat','depth','table','x','y','z']]
X.shape
# Out:
# (53940, 10)

# %% [markdown]
# #train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.7,random_state=2529)

# %% [markdown]
# #Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()

# %% [markdown]
# #Model Fitting

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# #Model Testing

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([1080.,  706., 3199., ...,  529.,  672., 5889.])

# %% [markdown]
# #Accuracy Check

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error,mean_absolute_percentage_error

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 3.603448275862069

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.0047733132758817996

# %%
mean_squared_error(y_test,y_test)
# Out:
# 0.0
